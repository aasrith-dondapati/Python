# %% [markdown]
# List

# %% [markdown]
# List Creation

# %%
list1=[]

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2=[10,30,60] # List of integers

# %%
list3=[10.24,28.78,78.98] # List of float numbers

# %%
list4=['one','two','three'] # List of Strings

# %%
list5=['AD',25,[30,60],[100,150]] # Nested List

# %%
list6=[100,'AD',190.728] # List of mixed datatypes

# %%
list7=['AD', 25,[30,60],[100,150],{'DR','solutions'}]

# %%
len(list7) # lenght of list
# Out:
# 5

# %% [markdown]
# List Indexing

# %%
list6[2]
# Out:
# 190.728

# %%
list5[0]
# Out:
# 'AD'

# %%
list4[-2]
# Out:
# 'two'

# %%
list4[0][0] # Nested indexing- Access the first character of the first list element
# Out:
# 'o'

# %%
list5[-1]
# Out:
# [100, 150]

# %% [markdown]
# List Slicing

# %%
mylist=['one','two','three','four','one','three','four','one']

# %%
mylist[0:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[:]
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'four', 'one']

# %%
mylist[:2]
# Out:
# ['one', 'two']

# %%
mylist[3:]
# Out:
# ['four', 'one', 'three', 'four', 'one']

# %%
mylist[:-1]
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'four']

# %%
mylist[-3:]
# Out:
# ['three', 'four', 'one']

# %% [markdown]
# Add,Remove & Change Items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'four', 'one']

# %%
mylist.append('five')

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'four', 'one', 'five']

# %%
mylist.insert(8,'six')

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'four', 'one', 'six', 'five']

# %%
mylist.insert(1,'one')

# %%
mylist
# Out:
# ['one',
#  'one',
#  'two',
#  'three',
#  'four',
#  'one',
#  'three',
#  'four',
#  'one',
#  'six',
#  'five']

# %%
mylist.remove('one') # Remove item "one"

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'four', 'one', 'six', 'five']

# %%
mylist.pop() # Remove last item in the list
# Out:
# 'five'

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'four', 'one', 'six']

# %%
mylist.pop(5) # Remove last item at index 5
# Out:
# 'three'

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'one', 'four', 'one', 'six']

# %%
del mylist[4] # deletes the item at index 4
mylist
# Out:
# ['one', 'two', 'three', 'four', 'one', 'six']

# %%
# change the value of string
mylist[0]=1
mylist[1]=2
mylist[2]=3

# %%
mylist
# Out:
# [1, 2, 3, 'four', 'one', 'six']

# %%
mylist.clear() # delets all items in the list
mylist
# Out:
# []

# %% [markdown]
# Copy List

# %%
mylist=['one','two','three','four','five','six','seven','eight','nine']

# %%
mylist1=mylist # creates a new reference list

# %%
id(mylist1),id(mylist)
# Out:
# (5848332928, 5848332928)

# %%
mylist2=mylist.copy()

# %%
id(mylist2) # address of mylist2 is different from mylist
# Out:
# 5848301376

# %%
mylist[0]=1

# %%
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1
mylist2
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# Join Lists

# %%
list1=['one','two','three']
list2=['four','five','six']

# %%
list3=list1+list2
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
list1.extend(list2)
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %% [markdown]
# List Membership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
'one' in list1 # checks if one exist in list1
# Out:
# True

# %%
'ten' in list1 # checks if ten exist in list1
# Out:
# False

# %%
if 'three' in list1:
    print('Three is available in list1')
else:
    print('Three is not available in list1')
# Out:
# Three is available in list1

# %%
if 'ten' in list1:
    print('Ten is available in list1')
else:
    print('Ten is not available in list1')
# Out:
# Ten is not available in list1

# %% [markdown]
# Reverse & Sort list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
list1.reverse() # Reverse the list
list1
# Out:
# ['six', 'five', 'four', 'three', 'two', 'one']

# %%
list1=list1[::-1]
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
mylist3=[9,6,2,5,8,1]
mylist3.sort()
mylist3
# Out:
# [1, 2, 5, 6, 8, 9]

# %%
mylist3=[9,6,2,5,8,1]
mylist3.sort(reverse=True)
mylist3
# Out:
# [9, 8, 6, 5, 2, 1]

# %%
mylist3=[9,6,2,5,8,1]
sorted(mylist3)
# Out:
# [1, 2, 5, 6, 8, 9]

# %% [markdown]
# Loop through a list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
for i in list1:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')

# %% [markdown]
# Count

# %%
list10 =['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count('one')
# Out:
# 3

# %%
list10.count('three')
# Out:
# 2

# %% [markdown]
# All/Any

# %%
L1 = [1,2,3,4,0]

# %%
all(L1)
# Out:
# False

# %%
any(L1)
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
all(L2)
# Out:
# False

# %%
any(L2)
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
all(L3)
# Out:
# True

# %%
any(L3)
# Out:
# True
