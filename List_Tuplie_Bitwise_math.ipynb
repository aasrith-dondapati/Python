# %%
l=[]

# %%
l.append(10)
l.append(20)
l.append(30)
l.append(40)

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
l.sort() # parameter tunning

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
l.sort(reverse=True) # Hyperparameter tunning

# %%
l
# Out:
# [40, 30, 20, 10]

# %%
l2=['z','f','a','r']
l2.sort()

# %%
l2
# Out:
# ['a', 'f', 'r', 'z']

# %%
l2.sort(reverse=False)

# %%
l2
# Out:
# ['a', 'f', 'r', 'z']

# %%
int.__add__(2,3)
# Out:
# 5

# %%
int.__sub__(3,2)
# Out:
# 1

# %%
float.__sub__(3.3,2.3)
# Out:
# 1.0

# %% [markdown]
# Tuple

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=3,4,5,6,7
t1
# Out:
# (3, 4, 5, 6, 7)

# %%
type(t1)
# Out:
# tuple

# %%
t2=(10,20,30)
t2
# Out:
# (10, 20, 30)

# %%
type(t2)
# Out:
# tuple

# %%
t.count(1)
# Out:
# 0

# %%
t1.count(0)
# Out:
# 0

# %%
t1
# Out:
# (3, 4, 5, 6, 7)

# %%
t2
# Out:
# (10, 20, 30)

# %%
t2.count(11)
# Out:
# 0

# %%
t2.count(30)
# Out:
# 1

# %%
t1
# Out:
# (3, 4, 5, 6, 7)

# %%
t1[0]
# Out:
# 3

# %%
t1[[0]=11
# Out:
#   Cell In[76], line 1
#     t1[[0]=11
#           ^
# SyntaxError: invalid syntax

# %%
t1
# Out:
# (3, 4, 5, 6, 7)

# %%
t1*3
# Out:
# (3, 4, 5, 6, 7, 3, 4, 5, 6, 7, 3, 4, 5, 6, 7)

# %%
t1
# Out:
# (3, 4, 5, 6, 7)

# %%
t1.index(3)
# Out:
# 0

# %%
t1.index(5)
# Out:
# 2

# %%
t1.index(9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 t1.index(9)
#
# ValueError: tuple.index(x): x not in tuple

# %%
t1[:]
# Out:
# (3, 4, 5, 6, 7)

# %%
t1[2:]
# Out:
# (5, 6, 7)

# %%
t1[:2]
# Out:
# (3, 4)

# %%
for i in t1:
    print(i)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
for i in enumerate(t1):
    print(i)
# Out:
# (0, 3)
# (1, 4)
# (2, 5)
# (3, 6)
# (4, 7)

# %%
t5=('AD',14)
type(t5)
# Out:
# tuple

# %%
t5[0]
# Out:
# 'AD'

# %%
print(t5[0][0])
print(t5[0][1])
print(t5[0][2])
# Out:
# A
# D
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 print(t5[0][0])
#       2 print(t5[0][1])
# ----> 3 print(t5[0][2])
#
# IndexError: string index out of range

# %%
print(t5[0][2])
print(t5[0][0])
print(t5[0][1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(t5[0][2])
#       2 print(t5[0][0])
#       3 print(t5[0][1])
#
# IndexError: string index out of range

# %% [markdown]
# Bitwise Operator

# %% [markdown]
# Compliment

# %%
~0
# Out:
# -1

# %%
~1
# Out:
# -2

# %%
~10
# Out:
# -11

# %%
~-1
# Out:
# 0

# %%
~54
# Out:
# -55

# %%
12&13 # AND Operator
# Out:
# 12

# %%
12|13 #OR Opeartor
# Out:
# 13

# %%
bin(13)
# Out:
# '0b1101'

# %%
print(bin(35))
print(bin(40))
# Out:
# 0b100011
# 0b101000

# %%
35&40
# Out:
# 32

# %%
35|40
# Out:
# 43

# %%
12^13 #XOR Operator
# Out:
# 1

# %%
25^30
# Out:
# 7

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10<<2
# Out:
# 40

# %%
10>>1
# Out:
# 5

# %%
 10>>2
# Out:
# 2

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
x=sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 x=sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math # math is module

# %%
x=math.sqrt(25)
x
# Out:
# 5.0

# %%
x1=math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
x2=math.floor(2.9) # as the number is between 2 and 3 floor gives the output as 2
x2
# Out:
# 2

# %%
x3=math.ceil(2.9) # as the number is between 2 and 3 floor gives the output as 3
x3
# Out:
# 3
