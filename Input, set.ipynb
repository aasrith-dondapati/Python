# %% [markdown]
# Math

# %%
import math as m
m.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt,pow
pow(2,3)
# Out:
# 8.0

# %%
round(pow(2,3))
# Out:
# 8

# %% [markdown]
#  Input Functions

# %%
x=input()
y=input()
z=x+y
print(z) # console is wating for user to enter input
# Out:
#  5
#  6
# 56

# %%
x1=input('Enter the 1st Number')
y1=input('Enter the 2nd Number')
z=x+y
print(z)
# Out:
# Enter the 1st Number 3
# Enter the 2nd Number 4
# 34

# %%
x1=input('Enter the 1st Number')
a1=int(x1)
y1=input('Enter the 2nd Number')
b1=int(y1)
z1=a1+b1
print(z1)
# Out:
# Enter the 1st Number 2
# Enter the 2nd Number 5
# 7

# %%
x1=int(input('Enter the 1st Number'))
y1=int(input('Enter the 2nd Number'))
z1=x1+y1
print(z1)
# Out:
# Enter the 1st Number 4
# Enter the 2nd Number 6
# 10

# %%
ch=input('enter a char')
print(ch)
# Out:
# enter a char hello
# hello

# %%
ch=input('enter a char')[0]
print(ch)
# Out:
# enter a char hello
# h

# %%
ch1=input('enter a char')[0:5]
print(ch1)
# Out:
# enter a char Have a Good Day
# Have

# %%
ch1=input('enter a char')[0:8]
print(ch1)
# Out:
# enter a char Have a Good Day
# Have a G

# %%
ch=input('enter a char')
print(ch)
# Out:
# enter a char 2+3
# 2+3

# %%
ch3=int(input('enter an expression'))
print(ch3)
# Out:
# enter an expression 2+3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 ch3=int(input('enter an expression'))
#       2 print(ch3)
#
# ValueError: invalid literal for int() with base 10: '2+3'

# %%
ch3=eval(input('enter an expression'))
print(ch3)
# Out:
# enter an expression 2+3+9-1
# 13

# %% [markdown]
# Set

# %%
s={}
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s1=set()
s1
# Out:
# set()

# %%
type(s1)
# Out:
# set

# %%
s1
# Out:
# set()

# %%
s2={200,3,1,20,10,10}
s2
# Out:
# {1, 3, 10, 20, 200}

# %%
s3={'d', 'e','a','w'}
s3
# Out:
# {'a', 'd', 'e', 'w'}

# %%
s4={1,'m',2.3,2+3j}
s4
# Out:
# {(2+3j), 1, 2.3, 'm'}

# %%
s4.add(1000)
s4
# Out:
# {(2+3j), 1, 1000, 2.3, 'm'}

# %%
s4.add(1000,1000)
s4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 s4.add(1000,1000)
#       2 s4
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
s5=s3.copy()
s5
# Out:
# {'a', 'd', 'e', 'w'}

# %%
s4
# Out:
# {(2+3j), 1, 1000, 2.3, 'm'}

# %%
len(s4)
# Out:
# 5

# %%
s4[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 s4[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s4[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 s4[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s3
# Out:
# {'a', 'd', 'e', 'w'}

# %%
s3[0]='n'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 s3[0]='n'
#
# TypeError: 'set' object does not support item assignment

# %%
s3.add('o')
s3
# Out:
# {'a', 'd', 'e', 'o', 'w'}

# %%
s3.pop()
s3
# Out:
# {'d', 'e', 'o', 'w'}

# %%
s2
# Out:
# {1, 3, 10, 20, 200}

# %%
s2.pop()
s2
# Out:
# {3, 10, 20, 200}

# %%
s2.pop(2)
s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 s2.pop(2)
#       2 s2
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s2
# Out:
# {3, 10, 20, 200}

# %%
s2.remove()
s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 s2.remove()
#       2 s2
#
# TypeError: set.remove() takes exactly one argument (0 given)

# %%
s2.remove(10)
s2
# Out:
# {3, 20, 200}

# %%
s2
# Out:
# {3, 20, 200}

# %%
s2.discard(500)
s2
# Out:
# {3, 20, 200}

# %%
s2.discard(200)
s2
# Out:
# {3, 20}

# %%
num = int(input("Enter a number: "))
print("Square:", num ** 2)
# Out:
# Enter a number:  2
# Square: 4

# %%
values = input("Enter comma-separated values: ").split(',')
# Out:
# Enter comma-separated values:  1,2,3,4

# %%
a = input("Enter first value: ")
b = input("Enter second value: ")
a, b = b, a
print(f"Swapped values: a = {a}, b = {b}")
# Out:
# Enter first value:  1
# Enter second value:  2
# Swapped values: a = 2, b = 1

# %%
from datetime import datetime
date_str = input("Enter a date (YYYY-MM-DD): ")
date = datetime.strptime(date_str, "%Y-%m-%d")
print("Entered date:", date)
# Out:
# Enter a date (YYYY-MM-DD):  2025-02-01
# Entered date: 2025-02-01 00:00:00

# %%
numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))
print("Maximum number:", max(numbers))
# Out:
# Enter numbers separated by spaces:  2 3 5 23 34 554
# Maximum number: 554

# %%
text = input("Enter a sentence: ")
words = text.split()
longest_word = max(words, key=len)
print("Longest word:", longest_word)
# Out:
# Enter a sentence:  have a good day
# Longest word: have
