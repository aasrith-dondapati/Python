# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# Varilable

# %%
a=5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
id(a)
# Out:
# 4312375184

# %%
b=1.2
b
# Out:
# 1.2

# %%
type(b)
# Out:
# float

# %%
age=25
print(age)
# Out:
# 25

# %%
name="AD"
print(name)
# Out:
# AD

# %%
price=21.09
print(price)
# Out:
# 21.09

# %%
is_active=True
print(is_active)
# Out:
# True

# %% [markdown]
# Rules to define Python Variable

# %%
a=10
a
# Out:
# 10

# %%
a1=10
a1
# Out:
# 10

# %%
Def=20
Def
# Out:
# 20

# %%
a_=30

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# Data Type (Primitive)
# - Int
# - Float
# - Complex
# - Bool
# - String

# %%
i=5
print(i)
print(type(i))
# Out:
# 5
# <class 'int'>

# %%
f=110.78
print(f)
print(type(f))
# Out:
# 110.78
# <class 'float'>

# %%
f1=3e0
print(f1)
print(type(f1))
# Out:
# 3.0
# <class 'float'>

# %%
True+False
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
False+False
# Out:
# 0

# %%
True+(False*True)-False
# Out:
# 1

# %%
True+(False*True)-True
# Out:
# 0

# %%
True+False*True-False
# Out:
# 1

# %%
b=True+(False*True)-True
b
# Out:
# 0

# %%
a=2
b=6
c=a+b
print('The sum of',a,'and',b,'is=',c)
# Out:
# The sum of 2 and 6 is= 8

# %%
c=10+20j
d=30+40j
print(c+d)
print(type(c))
# Out:
# (40+60j)
# <class 'complex'>

# %%
c-d
# Out:
# (-20-20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %% [markdown]
# String

# %%
s='AD'
print(s)
print(type(s))
# Out:
# AD
# <class 'str'>

# %%
s1='A
D'
s1
# Out:
#   Cell In[3], line 1
#     s1='A
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s2="A
D"
s2
# Out:
#   Cell In[5], line 1
#     s2="A
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s3='''A
D'''
s3
# Out:
# 'A\nD'

# %%
s4='Have a good day'
s4
# Out:
# 'Have a good day'

# %%
for i in s4:
    print(i)
# Out:
# H
# a
# v
# e
#
# a
#
# g
# o
# o
# d
#
# d
# a
# y

# %%
s4
# Out:
# 'Have a good day'

# %%
s4[3] #forward indexing
# Out:
# 'e'

# %%
s4[10]
# Out:
# 'd'

# %%
s4[15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s4[15]
#
# IndexError: string index out of range

# %%
s4[-4] #backward indexing
# Out:
# ' '

# %%
s4[0:4]
# Out:
# 'Have'

# %%
s4[-6:-3]
# Out:
# 'od '

# %%
s4[0:14:3]
# Out:
# 'He od'

# %%
s1='Hello'
s2=' AD'
s3=s1+s2
s3
# Out:
# 'Hello AD'

# %% [markdown]
# Operators

# %%
int._add_(5,6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 int._add_(5,6)
#
# AttributeError: type object 'int' has no attribute '_add_'

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
# help>  modules
# Please wait a moment while I gather a list of all available modules...
# /opt/anaconda3/lib/python3.12/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# ...

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %% [markdown]
# Type Casting
# - Convert from one datatype to other data type
# - From all other datatype into INT, Complex, Float, Bool

# %%
int(2.3) #float to int
# Out:
# 2

# %%
int(True) #bool to int
# Out:
# 1

# %%
int(1+2j) # cannot cast complex to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10') # string to int
# Out:
# 10

# %%
float(100)
# Out:
# 100.0

# %%
float(False)
# Out:
# 0.0

# %%
float(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float(10,20,30)
#
# TypeError: float expected at most 1 argument, got 3

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(2,4)
# Out:
# (2+4j)

# %%
complex(2,4,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 complex(2,4,6)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(True, False)
# Out:
# (1+0j)

# %%
complex(False, True)
# Out:
# 1j

# %%
complex('20')
# Out:
# (20+0j)

# %%
str(10)
# Out:
# '10'

# %%
str(109.190)
# Out:
# '109.19'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
bool(3)
# Out:
# True
