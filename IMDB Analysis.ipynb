# %%
import pandas as pd

# %%
ratings = pd.read_csv(r'/Users/aasrithdondapati/Desktop/DataScience and AI/Python/IMDB Analysis using Pandas/archive/rating.csv')

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.head(1)
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47

# %%
tags = pd.read_csv(r'/Users/aasrithdondapati/Desktop/DataScience and AI/Python/IMDB Analysis using Pandas/archive/tag.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.head(1)
# Out:
#    userId  movieId          tag            timestamp
# 0      18     4141  Mark Waters  2009-04-24 18:19:40

# %%
movies = pd.read_csv(r'/Users/aasrithdondapati/Desktop/DataScience and AI/Python/IMDB Analysis using Pandas/archive/movie.csv')

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.head(1)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465564 rows x 3 columns]

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %% [markdown]
# Series

# %%
tags_0 = tags.iloc[0]
print(tags_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
type(tags_0)
# Out:
# pandas.core.series.Series

# %%
tags_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags_0['userId']
# Out:
# 18

# %%
'rating' in tags_0
# Out:
# False

# %%
tags_0.name
# Out:
# 0

# %%
tags_0 = tags_0.rename('FirstRow')
tags_0.name
# Out:
# 'FirstRow'

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,1000]]
# Out:
#       userId  movieId                   tag
# 0         18     4141           Mark Waters
# 11        65     1783         noir thriller
# 1000     359    69526  needed more autobots

# %% [markdown]
# Descriptive Statistics

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating'] > 10
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %%
filter2 = ratings['rating'] > 0
print(filter2)
filter2.all()
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#             ...
# 20000258    True
# 20000259    True
# 20000260    True
# 20000261    True
# 20000262    True
# Name: rating, Length: 20000263, dtype: bool
# True

# %% [markdown]
# Data Cleaning: Handling Missing Data

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any().any()
# Out:
# False

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags.isnull().any().any()
# Out:
# True

# %%
tags=tags.dropna()

# %%
tags.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt # visualization
import seaborn as sns # distribution visualization

# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2

import warnings
warnings.filterwarnings('ignore') # os error

# %%
ratings.hist(column='rating')
plt.show()
plt.close()

# %%
ratings.boxplot(column='rating')
plt.show()

# %% [markdown]
# Slicing Out Columns

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-100:]
# Out:
#           userId  movieId  rating
# 20000163  138493     7347     4.5
# 20000164  138493     7361     5.0
# 20000165  138493     7371     5.0
# 20000166  138493     7416     4.5
# 20000167  138493     7438     5.0
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [100 rows x 3 columns]

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(kind = 'bar')
plt.show()

# %% [markdown]
# Filters for Selecting Rows

# %%
is_highly_rated = ratings['rating'] >=5.0
ratings[is_highly_rated][30:50]
# Out:
#      userId  movieId  rating
# 239       3       50     5.0
# 242       3      175     5.0
# 244       3      223     5.0
# 245       3      260     5.0
# 246       3      316     5.0
# 247       3      318     5.0
# 248       3      329     5.0
# 252       3      457     5.0
# 253       3      480     5.0
# 254       3      490     5.0
# 256       3      541     5.0
# 258       3      593     5.0
# 263       3      858     5.0
# 264       3      904     5.0
# 267       3      924     5.0
# 268       3      953     5.0
# 271       3     1060     5.0
# 272       3     1073     5.0
# 275       3     1084     5.0
# 276       3     1089     5.0

# %%
is_action = movies['genres'].str.contains('Action')
movies[is_action][5:15]
# Out:
#     movieId                                      title  \
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                            genres
# 22          Action|Crime|Thriller
# 41             Action|Crime|Drama
# 43       Action|Adventure|Fantasy
# 50          Action|Drama|Thriller
# 65         Action|Sci-Fi|Thriller
# 69  Action|Comedy|Horror|Thriller
# 70                         Action
# 75         Action|Sci-Fi|Thriller
# 77    Action|Crime|Drama|Thriller
# ...

# %%
movies[is_action].head(10)
# Out:
#     movieId                                      title  \
# 5         6                                Heat (1995)
# 8         9                        Sudden Death (1995)
# 9        10                           GoldenEye (1995)
# 14       15                    Cutthroat Island (1995)
# 19       20                         Money Train (1995)
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
#
#                                 genres
# 5                Action|Crime|Thriller
# 8                               Action
# 9            Action|Adventure|Thriller
# 14            Action|Adventure|Romance
# 19  Action|Comedy|Crime|Drama|Thriller
# 22               Action|Crime|Thriller
# 41                  Action|Crime|Drama
# ...
